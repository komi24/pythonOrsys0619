# %%
import pandas as pd

dataframe = pd.read_csv("./train.csv")

# %%
dataframe.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
dataframe.describe()
dataframe['age'].describe()
# dataframe['age'].plot()
dataframe['age'].hist(bins=16)

# %%
dataframe.plot.scatter('age', 'fare')

# %%
df = dataframe.sort_values('age')
df.plot('age', 'fare')

# %%
survecu = dataframe[dataframe['survived'] == 1]
femmes = dataframe[(dataframe['sex'] == 'female') & (dataframe['survived'] == 0)]
femmes['age'].mean()
femmes['age'].std()
# Out:
# 13.61859103671877

# %%
def print_mean_std(df, champs):
    print(
            """
            Moyenne survivants : %d; Std : %d.
            """ % (survivants[champs].mean(), survivants[champs].std())
    )
    
# Moyenne et std des ages des survivants
survivants = dataframe[dataframe['survived']==1]
print(
        """
        Moyenne survivants : %d; Std : %d.
        """ % (survivants['age'].mean(), survivants['age'].std())
)


# Moyenne et std des ages des morts
morts = dataframe[dataframe['survived']==0]
print(f"Moyenne survivants : { morts.mean() }; Std : {morts.std()}.")

# Moyenne et std des ages des survivants hommes
# Moyenne et std des ages des morts femmes

# Afficher un nuage de points (scatter) fare/age pour hommes qui ont survécu
# Afficher un nuage de points (scatter) fare/age pour hommes qui sont morts
# Afficher un nuage de points (scatter) fare/age pour femmes qui ont survécu
# Afficher un nuage de points (scatter) fare/age pour femmes qui sont morts

mickael.bolnet@gmail.com
# Out:
#         Moyenne survivants : 28; Std : 14.
#
# Moyenne survivants : survived     0.000000
# pclass       2.531876
# age         30.626179
# sibsp        0.553734
# parch        0.329690
# fare        22.117887
# dtype: float64; Std : survived     0.000000
# pclass       0.735805
# age         14.172110
# sibsp        1.288399
# parch        0.823166
# fare        31.388207
# dtype: float64.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-2fe4338517fb> in <module>
#      20 # Afficher un nuage de points (scatter) fare/age pour femmes qui sont morts
#      21
# ---> 22 mickael.bolnet@gmail.com
#
# NameError: name 'mickael' is not defined
